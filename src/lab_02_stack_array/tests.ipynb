# %% [markdown]
# ### **Lab 2: Array-Based Stack Checklist**
#
# ---
#
# #### **`Stack_array.py` Module**
#
# -   [ ] **Setup**: Copy the provided `Stack_array.py` template code into your `login_data_structures` project.
#
# -   [ ] **Implement `Stack` Methods**: Complete the following methods in the `Stack` class:
#     -   [ ] `is_empty()`
#     -   [ ] `push(value)`
#     -   [ ] `pop()`
#     -   [ ] `peek()`
#
# -   [ ] **Testing `Stack_array`**:
#     -   [ ] Thoroughly test your `Stack_array.py` module to ensure all methods work as expected.
#
# ---
#
# #### **`utilities.py` Module**
#
# -   [ ] **Create `utilities.py`**: Add a new module named `utilities.py` to your `login_data_structures` project.
#
# -   [ ] **Implement `array_to_stack`**: Write and test the following function in `utilities.py`.
#
#     ```python
#     def array_to_stack(stack, source):
#         """
#         -------------------------------------------------------
#         Pushes contents of source onto Stack. At finish, source is empty.
#         Last value in source is at bottom of Stack,
#         first value in source is on top of Stack.
#         Use: array_to_stack(stack, source)
#         -------------------------------------------------------
#         Parameters:
#             stack - a Stack object (Stack)
#             source - a Python list (list)
#         Returns:
#             None
#         -------------------------------------------------------
#         """
#     ```
#
# -   [ ] **Implement `stack_to_array`**: Write and test the following function in `utilities.py`.
#     *Hint: Running `array_to_stack` followed by `stack_to_array` should reverse the contents of the original list.*
#
#     ```python
#     def stack_to_array(stack, target):
#         """
#         -------------------------------------------------------
#         Pops contents of Stack into target. At finish, Stack is empty.
#         Top value of Stack is at end of target,
#         bottom value of Stack is at beginning of target.
#         Use: stack_to_array(stack, target)
#         -------------------------------------------------------
#         Parameters:
#             stack - a Stack object (Stack)
#             target - a Python list (list)
#         Returns:
#             None
#         -------------------------------------------------------
#         """
#     ```
#
# -   [ ] **Implement `stack_test`**: Write and test the following function in `utilities.py`.
#
#     ```python
#     def stack_test(source):
#         """
#         -------------------------------------------------------
#         Tests the methods of Stack for empty and
#         non-empty Stacks using the data in source:
#         is_empty, push, pop, peek
#         (Testing pop and peek while empty throws exceptions)
#         Use: stack_test(source)
#         -------------------------------------------------------
#         Parameters:
#             source - list of data (list of ?)
#         Returns:
#             None
#         -------------------------------------------------------
#         """
#     ```
#
# -   [ ] **Testing `utilities`**:
#     -   [ ] Test `stack_test` using a list of integers.
#     -   [ ] Re-run `stack_test`, this time using a list of `Food` objects from `foods.txt`.
